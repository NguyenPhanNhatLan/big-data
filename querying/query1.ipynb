# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Querying").getOrCreate()

# %%
df1 = spark.read.csv("D:/HK6/DỮ LIỆU LỚN VÀ ỨNG DỤNG/ĐACK/big-data/data_source/flat.csv", header=True, inferSchema=True)
df1.createOrReplaceTempView("flat")

# %%
df2 = spark.read.csv("D:/HK6/DỮ LIỆU LỚN VÀ ỨNG DỤNG/ĐACK/big-data/data_source/lease.csv", header=True, inferSchema=True)
df2.createOrReplaceTempView("lease")

# %%
df3 = spark.read.csv("D:/HK6/DỮ LIỆU LỚN VÀ ỨNG DỤNG/ĐACK/big-data/data_source/location.csv", header=True, inferSchema=True)
df3.createOrReplaceTempView("location")

# %%
df4 = spark.read.csv("D:/HK6/DỮ LIỆU LỚN VÀ ỨNG DỤNG/ĐACK/big-data/data_source/time.csv", header=True, inferSchema=True)
df4.createOrReplaceTempView("time")

# %%
df5 = spark.read.csv("D:/HK6/DỮ LIỆU LỚN VÀ ỨNG DỤNG/ĐACK/big-data/data_source/resale.csv", header=True, inferSchema=True)
df5.createOrReplaceTempView("resale")

# %% [markdown]
# ## QUERYING

# %%
query = spark.sql("""select * from flat""")
query.show()
# Out:
# +-------+---------+--------------+------------+--------------+
# |flat_id|flat_type|    flat_model|storey_range|floor_area_sqm|
# +-------+---------+--------------+------------+--------------+
# |      1|   2 ROOM|      Improved|    10 TO 12|          44.0|
# |      2|   3 ROOM|New Generation|    01 TO 03|          67.0|
# |      3|   3 ROOM|New Generation|    04 TO 06|          68.0|
# |      4|   3 ROOM|New Generation|    01 TO 03|          68.0|
# |      5|   3 ROOM|New Generation|    04 TO 06|          67.0|
# |      6|   3 ROOM|New Generation|    10 TO 12|          67.0|
# |      7|   3 ROOM|New Generation|    07 TO 09|          67.0|
# |      8|   3 ROOM|New Generation|    07 TO 09|          68.0|
# |      9|   3 ROOM|New Generation|    04 TO 06|          73.0|
# |     10|   3 ROOM|New Generation|    07 TO 09|          74.0|
# |     11|   3 ROOM|New Generation|    10 TO 12|          73.0|
# |     12|   3 ROOM|New Generation|    10 TO 12|          82.0|
# |     13|   3 ROOM|New Generation|    07 TO 09|          82.0|
# |     14|   3 ROOM|New Generation|    01 TO 03|          81.0|
# |     15|   4 ROOM|New Generation|    10 TO 12|          92.0|
# |     16|   4 ROOM|New Generation|    07 TO 09|          91.0|
# |     17|   4 ROOM|New Generation|    01 TO 03|          94.0|
# |     18|   4 ROOM|New Generation|    01 TO 03|          92.0|
# |     19|   4 ROOM|New Generation|    01 TO 03|          98.0|
# |     20|   4 ROOM|New Generation|    04 TO 06|          97.0|
# +-------+---------+--------------+------------+--------------+
# only showing top 20 rows

# %%
query = spark.sql("""select * from lease""")
query.show()
# Out:
# +--------+-------------------+------------------+
# |lease_id|lease_commence_date|   remaining_lease|
# +--------+-------------------+------------------+
# |       1|               1979|61 years 04 months|
# |       2|               1978|60 years 07 months|
# |       3|               1980|62 years 05 months|
# |       4|               1980| 62 years 01 month|
# |       5|               1981|          63 years|
# |       6|               1979|61 years 06 months|
# |       7|               1976|58 years 04 months|
# |       8|               1977|59 years 08 months|
# |       9|               1977|59 years 06 months|
# |      10|               1978|          60 years|
# |      11|               1980|62 years 08 months|
# |      12|               1979|          61 years|
# |      13|               1978|60 years 10 months|
# |      14|               1977|59 years 03 months|
# |      15|               1979|61 years 05 months|
# |      16|               1978|60 years 04 months|
# |      17|               1980|          62 years|
# |      18|               1978|60 years 03 months|
# |      19|               1981|63 years 09 months|
# |      20|               1979| 61 years 01 month|
# +--------+-------------------+------------------+
# only showing top 20 rows

# %%
query = spark.sql("""select * from location""")
query.show()
# Out:
# +----------+-----------------+-----+-----------+
# |      town|      street_name|block|location_id|
# +----------+-----------------+-----+-----------+
# |ANG MO KIO|ANG MO KIO AVE 10|  406|          1|
# |ANG MO KIO| ANG MO KIO AVE 4|  108|          2|
# |ANG MO KIO| ANG MO KIO AVE 5|  602|          3|
# |ANG MO KIO|ANG MO KIO AVE 10|  465|          4|
# |ANG MO KIO| ANG MO KIO AVE 5|  601|          5|
# |ANG MO KIO| ANG MO KIO AVE 5|  150|          6|
# |ANG MO KIO|ANG MO KIO AVE 10|  447|          7|
# |ANG MO KIO| ANG MO KIO AVE 1|  218|          8|
# |ANG MO KIO| ANG MO KIO AVE 3|  571|          9|
# |ANG MO KIO|ANG MO KIO AVE 10|  534|         10|
# |ANG MO KIO| ANG MO KIO AVE 3|  233|         11|
# |ANG MO KIO| ANG MO KIO AVE 3|  235|         12|
# |ANG MO KIO| ANG MO KIO AVE 1|  219|         13|
# |ANG MO KIO|ANG MO KIO AVE 10|  536|         14|
# |ANG MO KIO| ANG MO KIO AVE 3|  230|         15|
# |ANG MO KIO| ANG MO KIO AVE 3|  570|         16|
# |ANG MO KIO| ANG MO KIO AVE 4|  624|         17|
# |ANG MO KIO|ANG MO KIO AVE 10|  441|         18|
# |ANG MO KIO| ANG MO KIO AVE 9|  625|         19|
# |ANG MO KIO| ANG MO KIO AVE 3|  119|         20|
# +----------+-----------------+-----+-----------+
# only showing top 20 rows

# %%
query = spark.sql("""select * from time""")
query.show()
# Out:
# +-------+-------------------+----+---------+-------+
# |time_id|              month|year|month_num|quarter|
# +-------+-------------------+----+---------+-------+
# |      1|2017-01-01 00:00:00|2017|        1|      1|
# |      2|2017-02-01 00:00:00|2017|        2|      1|
# |      3|2017-03-01 00:00:00|2017|        3|      1|
# |      4|2017-04-01 00:00:00|2017|        4|      2|
# |      5|2017-05-01 00:00:00|2017|        5|      2|
# |      6|2017-06-01 00:00:00|2017|        6|      2|
# |      7|2017-07-01 00:00:00|2017|        7|      3|
# |      8|2017-08-01 00:00:00|2017|        8|      3|
# |      9|2017-09-01 00:00:00|2017|        9|      3|
# |     10|2017-10-01 00:00:00|2017|       10|      4|
# |     11|2017-11-01 00:00:00|2017|       11|      4|
# |     12|2017-12-01 00:00:00|2017|       12|      4|
# |     13|2018-01-01 00:00:00|2018|        1|      1|
# |     14|2018-02-01 00:00:00|2018|        2|      1|
# |     15|2018-03-01 00:00:00|2018|        3|      1|
# |     16|2018-04-01 00:00:00|2018|        4|      2|
# |     17|2018-05-01 00:00:00|2018|        5|      2|
# |     18|2018-06-01 00:00:00|2018|        6|      2|
# |     19|2018-07-01 00:00:00|2018|        7|      3|
# |     20|2018-08-01 00:00:00|2018|        8|      3|
# +-------+-------------------+----+---------+-------+
# only showing top 20 rows

# %%
query = spark.sql("""select * from resale limit 50""")
query.show()
# Out:
# +--------------+-------+-----------+-------+--------+------------+
# |transaction_id|time_id|location_id|flat_id|lease_id|resale_price|
# +--------------+-------+-----------+-------+--------+------------+
# |             1|      1|          1|      1|       1|    232000.0|
# |             2|      1|          2|      2|       2|    250000.0|
# |             3|      1|          3|      2|       3|    262000.0|
# |             4|      1|          4|      2|       4|    265000.0|
# |             5|      1|          5|      2|       3|    265000.0|
# |             6|      1|          6|      2|       5|    275000.0|
# |             7|      1|          7|      2|       6|    280000.0|
# |             8|      1|          8|      2|       7|    285000.0|
# |             9|      1|          7|      2|       6|    285000.0|
# |            10|      1|          9|      2|       1|    285000.0|
# |            11|      1|         10|      2|       4|    288500.0|
# |            12|      1|         11|      2|       8|    295000.0|
# |            13|      1|         12|      2|       8|    295000.0|
# |            14|      1|         13|      2|       9|    297000.0|
# |            15|      1|         14|      2|       4|    298000.0|
# |            16|      1|         15|      2|      10|    298000.0|
# |            17|      1|         16|      2|       1|    300000.0|
# |            18|      1|         17|      2|      11|    301000.0|
# |            19|      1|         18|      2|      12|    306000.0|
# |            20|      1|         19|      2|      11|    312000.0|
# +--------------+-------+-----------+-------+--------+------------+
# only showing top 20 rows

# %% [markdown]
# #### Top 10 town có giá resale trung bình cao nhất

# %%
query = spark.sql(""" 
select l.town, round(avg(r.resale_price), 2) as avg_price
from resale r
join location l on r.location_id = l.location_id
group by l.town
order by avg_price desc
limit 10""")
query.show()
# Out:
# +---------------+---------+
# |           town|avg_price|
# +---------------+---------+
# |    BUKIT TIMAH|745127.18|
# |         BISHAN|681674.59|
# |   CENTRAL AREA|662651.42|
# |     QUEENSTOWN|613601.76|
# |    BUKIT MERAH| 611584.0|
# |KALLANG/WHAMPOA|560016.94|
# |      PASIR RIS|556178.33|
# |  MARINE PARADE|543726.33|
# |      SERANGOON|536766.06|
# |       CLEMENTI|529834.95|
# +---------------+---------+

# %% [markdown]
# #### Top 10 town có giá resale trung bình thấp nhất

# %%
query = spark.sql(""" 
select l.town, round(avg(r.resale_price), 2) as avg_price
from resale r
join location l on r.location_id = l.location_id
group by l.town
order by avg_price asc
limit 10""")
query.show()
# Out:
# +-------------+---------+
# |         town|avg_price|
# +-------------+---------+
# |       YISHUN|425567.79|
# |  JURONG WEST|440497.02|
# |    WOODLANDS|449412.42|
# |  JURONG EAST|454757.37|
# |   ANG MO KIO|454931.11|
# |        BEDOK|457104.05|
# |    SEMBAWANG|460662.03|
# |CHOA CHU KANG|464323.24|
# |  BUKIT BATOK|468191.61|
# |BUKIT PANJANG|476334.33|
# +-------------+---------+

# %% [markdown]
# #### Top 20 căn hộ có giá resale cao nhất

# %%
query = spark.sql(""" 
select * 
from resale r
join location l on r.location_id = l.location_id
join flat f on r.flat_id = f.flat_id
join time t on r.time_id = t.time_id
join lease ls on r.lease_id = ls.lease_id
order by r.resale_price desc
limit 20""")
query.show()
# Out:
# +--------------+-------+-----------+-------+--------+------------+------------+----------------+-----+-----------+-------+---------+--------------+------------+--------------+-------+-------------------+----+---------+-------+--------+-------------------+------------------+
# |transaction_id|time_id|location_id|flat_id|lease_id|resale_price|        town|     street_name|block|location_id|flat_id|flat_type|    flat_model|storey_range|floor_area_sqm|time_id|              month|year|month_num|quarter|lease_id|lease_commence_date|   remaining_lease|
# +--------------+-------+-----------+-------+--------+------------+------------+----------------+-----+-----------+-------+---------+--------------+------------+--------------+-------+-------------------+----+---------+-------+--------+-------------------+------------------+
# |        180625|     90|       8814|      6|    4733|   1588000.0| BUKIT MERAH|    HENDERSON RD|  96A|       8814|      6|   3 ROOM|New Generation|    10 TO 12|          67.0|     90|2024-06-01 00:00:00|2024|        6|      2|    4733|               2019|          94 years|
# |        171082|     85|       5142|      7|    4662|   1568888.0|   TOA PAYOH|LOR 1A TOA PAYOH| 139A|       5142|      7|   3 ROOM|New Generation|    07 TO 09|          67.0|     85|2024-01-01 00:00:00|2024|        1|      1|    4662|               2012|87 years 04 months|
# |        171084|     85|       5567|      7|    4663|   1540000.0|   TOA PAYOH|LOR 1A TOA PAYOH| 138C|       5567|      7|   3 ROOM|New Generation|    07 TO 09|          67.0|     85|2024-01-01 00:00:00|2024|        1|      1|    4663|               2012|87 years 03 months|
# |        178657|     89|        274|     27|    4957|   1515000.0|CENTRAL AREA|   CANTONMENT RD|   1C|        274|     27|   4 ROOM|          DBSS|    19 TO 21|          91.0|     89|2024-05-01 00:00:00|2024|        5|      2|    4957|               2011|85 years 09 months|
# |        154543|     78|        199|     35|    4318|   1500000.0| BUKIT MERAH|    MOH GUAN TER|   50|        199|     35|   2 ROOM|      Improved|    04 TO 06|          45.0|     78|2023-06-01 00:00:00|2023|        6|      2|    4318|               1973|48 years 08 months|
# |        178310|     89|        125|      7|    4536|   1500000.0|      BISHAN|    BISHAN ST 24| 275A|        125|      7|   3 ROOM|New Generation|    07 TO 09|          67.0|     89|2024-05-01 00:00:00|2024|        5|      2|    4536|               2011|86 years 04 months|
# |        178316|     89|       4711|     20|    4731|   1500000.0|      BISHAN|    BISHAN ST 24|  286|       4711|     20|   4 ROOM|New Generation|    04 TO 06|          97.0|     89|2024-05-01 00:00:00|2024|        5|      2|    4731|               1992|67 years 04 months|
# |        158744|     80|       1265|     27|    4478|   1480000.0|CENTRAL AREA|   CANTONMENT RD|   1D|       1265|     27|   4 ROOM|          DBSS|    19 TO 21|          91.0|     80|2023-08-01 00:00:00|2023|        8|      3|    4478|               2011|86 years 05 months|
# |        171679|     86|       4711|     20|    4630|   1480000.0|      BISHAN|    BISHAN ST 24|  286|       4711|     20|   4 ROOM|New Generation|    04 TO 06|          97.0|     86|2024-02-01 00:00:00|2024|        2|      1|    4630|               1992|67 years 06 months|
# |        160209|     80|       5574|      7|    4385|   1460000.0|   TOA PAYOH|LOR 1A TOA PAYOH| 139B|       5574|      7|   3 ROOM|New Generation|    07 TO 09|          67.0|     80|2023-08-01 00:00:00|2023|        8|      3|    4385|               2012|87 years 09 months|
# |        165186|     83|       8861|      6|    4406|   1460000.0| BUKIT MERAH|    HENDERSON RD|  95C|       8861|      6|   3 ROOM|New Generation|    10 TO 12|          67.0|     83|2023-11-01 00:00:00|2023|       11|      4|    4406|               2019|94 years 06 months|
# |        169112|     85|       1178|      7|    4322|   1458000.0|      BISHAN|    BISHAN ST 24| 273B|       1178|      7|   3 ROOM|New Generation|    07 TO 09|          67.0|     85|2024-01-01 00:00:00|2024|        1|      1|    4322|               2011|86 years 08 months|
# |        160777|     81|       8296|     20|    4267|   1450000.0|      BISHAN|    BISHAN ST 24|  278|       8296|     20|   4 ROOM|New Generation|    04 TO 06|          97.0|     81|2023-09-01 00:00:00|2023|        9|      3|    4267|               1992|67 years 11 months|
# |        162995|     82|       8814|      6|    4270|   1450000.0| BUKIT MERAH|    HENDERSON RD|  96A|       8814|      6|   3 ROOM|New Generation|    10 TO 12|          67.0|     82|2023-10-01 00:00:00|2023|       10|      4|    4270|               2019|94 years 09 months|
# |        165184|     83|       8814|      6|    4363|   1450000.0| BUKIT MERAH|    HENDERSON RD|  96A|       8814|      6|   3 ROOM|New Generation|    10 TO 12|          67.0|     83|2023-11-01 00:00:00|2023|       11|      4|    4363|               2019|94 years 07 months|
# |        169461|     85|       2101|     27|    4691|   1450000.0|CENTRAL AREA|   CANTONMENT RD|   1A|       2101|     27|   4 ROOM|          DBSS|    19 TO 21|          91.0|     85|2024-01-01 00:00:00|2024|        1|      1|    4691|               2011| 86 years 01 month|
# |        173998|     87|       7872|      6|    4845|   1450000.0| BUKIT MERAH|   BOON TIONG RD|   9A|       7872|      6|   3 ROOM|New Generation|    10 TO 12|          67.0|     87|2024-03-01 00:00:00|2024|        3|      1|    4845|               2016|90 years 11 months|
# |        178654|     89|        274|     26|    4958|   1450000.0|CENTRAL AREA|   CANTONMENT RD|   1C|        274|     26|   4 ROOM|          DBSS|    13 TO 15|          90.0|     89|2024-05-01 00:00:00|2024|        5|      2|    4958|               2011|85 years 08 months|
# |        178313|     89|       1165|      8|    4792|   1448000.0|      BISHAN|    BISHAN ST 22|  241|       1165|      8|   3 ROOM|New Generation|    07 TO 09|          68.0|     89|2024-05-01 00:00:00|2024|        5|      2|    4792|               1992|67 years 03 months|
# |        163078|     82|        274|     27|    4536|   1438888.0|CENTRAL AREA|   CANTONMENT RD|   1C|        274|     27|   4 ROOM|          DBSS|    19 TO 21|          91.0|     82|2023-10-01 00:00:00|2023|       10|      4|    4536|               2011|86 years 04 months|
# +--------------+-------+-----------+-------+--------+------------+------------+----------------+-----+-----------+-------+---------+--------------+------------+--------------+-------+-------------------+----+---------+-------+--------+-------------------+------------------+

# %% [markdown]
# #### Top 2 căn hộ đắt tiền nhất mỗi năm

# %%
query = spark.sql(""" 
with t1 as
(select r.resale_price, f.flat_type, f.floor_area_sqm, l.town, t.year,
row_number() over (partition by t.year order by r.resale_price desc) as ranking
from resale r
join flat f on r.flat_id = f.flat_id
join location l on r.location_id = l.location_id
join time t on r.time_id = t.time_id)

select year, town, flat_type, floor_area_sqm, resale_price
from t1 where ranking in (1, 2)
order by year""")
query.show()
# Out:
# +----+---------------+---------+--------------+------------+
# |year|           town|flat_type|floor_area_sqm|resale_price|
# +----+---------------+---------+--------------+------------+
# |2017|         BISHAN|   3 ROOM|          67.0|   1180000.0|
# |2017|     QUEENSTOWN|   3 ROOM|          68.0|   1160000.0|
# |2018|KALLANG/WHAMPOA|EXECUTIVE|         147.0|   1185000.0|
# |2018|   CENTRAL AREA|   4 ROOM|          91.0|   1168000.0|
# |2019|KALLANG/WHAMPOA|   3 ROOM|          67.0|   1205000.0|
# |2019|    BUKIT MERAH|   3 ROOM|          67.0|   1200000.0|
# |2020|   CENTRAL AREA|   4 ROOM|          91.0|   1258000.0|
# |2020|   CENTRAL AREA|   4 ROOM|          91.0|   1248000.0|
# |2021|         BISHAN|   3 ROOM|          67.0|   1360000.0|
# |2021|     QUEENSTOWN|   3 ROOM|          70.0|   1328000.0|
# |2022|     QUEENSTOWN|   3 ROOM|          70.0|   1418000.0|
# |2022|    BUKIT MERAH|   3 ROOM|          67.0|   1400000.0|
# |2023|    BUKIT MERAH|   2 ROOM|          45.0|   1500000.0|
# |2023|   CENTRAL AREA|   4 ROOM|          91.0|   1480000.0|
# |2024|    BUKIT MERAH|   3 ROOM|          67.0|   1588000.0|
# |2024|      TOA PAYOH|   3 ROOM|          67.0|   1568888.0|
# +----+---------------+---------+--------------+------------+

# %% [markdown]
# #### Loại căn hộ phổ biến nhất ở từng town

# %%
query = spark.sql(""" 
with t1 as
(select f.flat_type, l.town, 
count(f.flat_id) as flat_count,
row_number() over (partition by l.town order by count(f.flat_id) desc) as rn
from resale r
join flat f on r.flat_id = f.flat_id
join location l on r.location_id = l.location_id
group by f.flat_type, l.town)

select town, flat_type, flat_count
from t1
where rn = 1
order by town 
""")
query.show()
# Out:
# +---------------+---------+----------+
# |           town|flat_type|flat_count|
# +---------------+---------+----------+
# |     ANG MO KIO|   3 ROOM|      7156|
# |          BEDOK|   3 ROOM|      8691|
# |         BISHAN|   3 ROOM|      2745|
# |    BUKIT BATOK|   3 ROOM|      5944|
# |    BUKIT MERAH|   3 ROOM|      5800|
# |  BUKIT PANJANG|   3 ROOM|      4862|
# |    BUKIT TIMAH|   3 ROOM|       363|
# |   CENTRAL AREA|   3 ROOM|       843|
# |  CHOA CHU KANG|   3 ROOM|      6601|
# |       CLEMENTI|   3 ROOM|      3794|
# |        GEYLANG|   3 ROOM|      3201|
# |        HOUGANG|   3 ROOM|      7695|
# |    JURONG EAST|   3 ROOM|      3243|
# |    JURONG WEST|   3 ROOM|      9225|
# |KALLANG/WHAMPOA|   3 ROOM|      4509|
# |  MARINE PARADE|   3 ROOM|      1101|
# |      PASIR RIS|   3 ROOM|      4866|
# |        PUNGGOL|   4 ROOM|      6788|
# |     QUEENSTOWN|   3 ROOM|      3840|
# |      SEMBAWANG|   3 ROOM|      3688|
# +---------------+---------+----------+
# only showing top 20 rows

# %% [markdown]
# #### Giá trung bình của từng loại căn hộ ở từng town

# %%
query = spark.sql(""" 
select l.town, f.flat_type, round(avg(r.resale_price), 2) as avg_price
from resale r
join flat f on r.flat_id = f.flat_id
join location l on r.location_id = l.location_id
group by l.town, f.flat_type
order by l.town
""")
query.show()
# Out:
# +-------------+---------+---------+
# |         town|flat_type|avg_price|
# +-------------+---------+---------+
# |   ANG MO KIO|   4 ROOM|755901.71|
# |   ANG MO KIO|   5 ROOM|878274.21|
# |   ANG MO KIO|   2 ROOM|243472.44|
# |   ANG MO KIO|   3 ROOM| 451416.8|
# |        BEDOK|   3 ROOM|441116.31|
# |        BEDOK|   2 ROOM|237313.69|
# |        BEDOK|   4 ROOM|667930.63|
# |        BEDOK|   5 ROOM|545685.41|
# |       BISHAN|   3 ROOM|640471.96|
# |       BISHAN|   4 ROOM| 893872.0|
# |  BUKIT BATOK|   5 ROOM|345007.53|
# |  BUKIT BATOK|   4 ROOM|652008.21|
# |  BUKIT BATOK|   3 ROOM| 443081.5|
# |  BUKIT MERAH|   3 ROOM| 640941.2|
# |  BUKIT MERAH|   5 ROOM|283071.71|
# |  BUKIT MERAH|   2 ROOM|293344.12|
# |  BUKIT MERAH|   4 ROOM|493876.58|
# |BUKIT PANJANG|   5 ROOM|264106.65|
# |BUKIT PANJANG|   3 ROOM| 468693.0|
# |BUKIT PANJANG|   4 ROOM|512897.65|
# +-------------+---------+---------+
# only showing top 20 rows

# %% [markdown]
# #### Con đường đắt giá nhất ở từng town

# %%
query = spark.sql(""" 
with t1 as
(select l.town, l.street_name, round(avg(r.resale_price), 2) as avg_price,
row_number() over (partition by l.town order by avg(r.resale_price) desc) as rn
from resale r
join location l on r.location_id = l.location_id
group by l.town, l.street_name
                  )

select street_name, town, avg_price
from t1
where rn = 1
order by avg_price desc
""")
query.show()
# Out:
# +----------------+---------------+----------+
# |     street_name|           town| avg_price|
# +----------------+---------------+----------+
# |   CANTONMENT RD|   CENTRAL AREA|1047515.93|
# |LOR 1A TOA PAYOH|      TOA PAYOH| 912498.24|
# |   BOON TIONG RD|    BUKIT MERAH| 903484.99|
# |ANG MO KIO ST 21|     ANG MO KIO| 885986.58|
# |    BOON KENG RD|KALLANG/WHAMPOA|  861857.4|
# |       TOH YI DR|    BUKIT TIMAH| 859650.61|
# |       DAWSON RD|     QUEENSTOWN| 853205.63|
# |        SIMS AVE|        GEYLANG|  833752.2|
# |    BISHAN ST 24|         BISHAN|  815478.2|
# |  CLEMENTI ST 13|       CLEMENTI| 784789.66|
# |   LENGKONG TIGA|          BEDOK| 779820.18|
# |   HOUGANG ST 21|        HOUGANG| 760499.25|
# |      SIMEI LANE|       TAMPINES| 728328.49|
# | PASIR RIS ST 41|      PASIR RIS|  712825.0|
# |  BT BATOK ST 22|    BUKIT BATOK| 706800.74|
# |       JELEBU RD|  BUKIT PANJANG| 675984.72|
# | SERANGOON AVE 1|      SERANGOON| 673681.58|
# |    YUNG PING RD|    JURONG WEST| 615689.94|
# |     TOH GUAN RD|    JURONG EAST| 612033.87|
# | COMPASSVALE BOW|       SENGKANG| 610677.75|
# +----------------+---------------+----------+
# only showing top 20 rows
